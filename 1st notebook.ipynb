# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nasa=pd.read_csv(r"C:\Users\ritik\Downloads\nasa\nasa.csv")

# %%
nasa.shape
# Out:
# (4687, 40)

# %%
nasa.head()
# Out:
#    Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0           3703080  3703080                21.6            0.127220
# 1           3723955  3723955                21.3            0.146068
# 2           2446862  2446862                20.3            0.231502
# 3           3092506  3092506                27.4            0.008801
# 4           3514799  3514799                21.6            0.127220
#
#    Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 0            0.284472         127.219878         284.472296
# 1            0.326618         146.067964         326.617897
# 2            0.517654         231.502122         517.654482
# 3            0.019681           8.801465          19.680675
# 4            0.284472         127.219878         284.472296
#
#    Est Dia in Miles(min)  Est Dia in Miles(max)  Est Dia in Feet(min)  ...  \
# 0               0.079051               0.176763            417.388066  ...
# ...

# %%
from pandas.tseries import converter
converter.register()
# Out:
# c:\users\ritik\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tseries.converter.register' has been moved and renamed to 'pandas.plotting.register_matplotlib_converters'.

# %%
Z=pd.read_csv(r"C:\Users\ritik\Downloads\nasa\nasa.csv")

# %%
Z.drop(['Hazardous'], axis = 1)
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080              21.600            0.127220
# 1              3723955  3723955              21.300            0.146068
# 2              2446862  2446862              20.300            0.231502
# 3              3092506  3092506              27.400            0.008801
# 4              3514799  3514799              21.600            0.127220
# ...                ...      ...                 ...                 ...
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %%
Z.drop([20])
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080              21.600            0.127220
# 1              3723955  3723955              21.300            0.146068
# 2              2446862  2446862              20.300            0.231502
# 3              3092506  3092506              27.400            0.008801
# 4              3514799  3514799              21.600            0.127220
# ...                ...      ...                 ...                 ...
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %%
y=pd.read_csv(r"C:\Users\ritik\Downloads\nasa\nasa.csv" ,usecols = ['Hazardous'])

# %%
Z['Close_Approach_Date'] = pd.to_datetime(Z.Close_Approach_Date)

# %%
Z['Orbit_Determination_Date'] = pd.to_datetime(Z.Orbit_Determination_Date)

# %%
Z.iloc[0,:]
# Out:
# Absolute Magnitude                            21.6
# Est Dia in KM(min)                         0.12722
# Est Dia in KM(max)                        0.284472
# Est Dia in M(min)                           127.22
# Est Dia in M(max)                          284.472
#                                            ...
# Orbit_Determination_Is_quarter_end           False
# Orbit_Determination_Is_quarter_start         False
# Orbit_Determination_Is_year_end              False
# Orbit_Determination_Is_year_start            False
# Orbit_Determination_Elapsed             1491467760
# Name: 0, Length: 62, dtype: object

# %%
from fastai.tabular import add_datepart

# %%
import torch
from pandas.api.types import is_numeric_dtype
from datetime import date, datetime
import calendar

# %%
add_datepart(Z,'Close_Approach_Date')
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080              21.600            0.127220
# 1              3723955  3723955              21.300            0.146068
# 2              2446862  2446862              20.300            0.231502
# 3              3092506  3092506              27.400            0.008801
# 4              3514799  3514799              21.600            0.127220
# ...                ...      ...                 ...                 ...
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %%
add_datepart(Z,'Orbit_Determination_Date')
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080              21.600            0.127220
# 1              3723955  3723955              21.300            0.146068
# 2              2446862  2446862              20.300            0.231502
# 3              3092506  3092506              27.400            0.008801
# 4              3514799  3514799              21.600            0.127220
# ...                ...      ...                 ...                 ...
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %%
Z.fillna(Z.mean(), inplace=True)
Z.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
from sklearn.model_selection import train_test_split
Z_train, Z_test, y_train, y_test = train_test_split(Z, y, test_size = 0.20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-09bcb37e8e02> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 Z_train, Z_test, y_train, y_test = train_test_split(Z, y, test_size = 0.20)
#
# c:\users\ritik\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2116         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2117
# -> 2118     arrays = indexable(*arrays)
#    2119
#    2120     n_samples = _num_samples(arrays[0])
#
# c:\users\ritik\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     246     """
#     247     result = [_make_indexable(X) for X in iterables]
# --> 248     check_consistent_length(*result)
#     249     return result
#     250
#
# ...

# %%
Z.head()
# Out:
#    index  Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0      0           3703080  3703080                21.6            0.127220
# 1      1           3723955  3723955                21.3            0.146068
# 2      2           2446862  2446862                20.3            0.231502
# 3      3           3092506  3092506                27.4            0.008801
# 4      4           3514799  3514799                21.6            0.127220
#
#    Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 0            0.284472         127.219878         284.472296
# 1            0.326618         146.067964         326.617897
# 2            0.517654         231.502122         517.654482
# 3            0.019681           8.801465          19.680675
# 4            0.284472         127.219878         284.472296
#
#    Est Dia in Miles(min)  Est Dia in Miles(max)  ...  Orbit_Determination_Day  \
# ...

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
svclassifier.fit(Z_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-12f78b72d314> in <module>
#       1 from sklearn.svm import SVC
#       2 svclassifier = SVC(kernel='linear')
# ----> 3 svclassifier.fit(Z_train, y_train)
#
# c:\users\ritik\appdata\local\programs\python\python36\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     146         X, y = check_X_y(X, y, dtype=np.float64,
#     147                          order='C', accept_sparse='csr',
# --> 148                          accept_large_sparse=False)
#     149         y = self._validate_targets(y)
#     150
#
# ...

# %%
np.any(np.isnan(Z))

np.all(np.isfinite(Z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-adddbf5f3455> in <module>
# ----> 1 np.any(np.isnan(Z))
#       2
#       3 np.all(np.isfinite(Z))
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
# Out:
# Empty DataFrame
# ...

# %%
Z.head()
# Out:
# Empty DataFrame
# ...
